% %% [markdown]
% # Data visualization

% %% [markdown]
% ## Load the dataset

% %%
dataset = dataset.from_file("../data/dataset6.mat")
% Out:
% dataset =
%
%   dataset object with properties:
%
%          A: [200x3 double]
%          B: [200x3 double]
%          X: [400x3 double]
%       data: [400x4 double]
%          n: [1x1 double]
%          y: [400x1 double]

% %%
dataset.summary()
% Out:
%   dataset object with properties:
%
%          A: [200x3 double]
%          B: [200x3 double]
%          X: [400x3 double]
%       data: [400x4 double]
%          n: [1x1 double]
%          y: [400x1 double]
%
% rows: 400, columns: 4
%    30.1791   24.8121   42.8749    1.0000
%    48.0718   55.1398   69.9469    1.0000
%     6.1383   88.8610   76.7079   -1.0000
%    55.2615   52.0227   59.5175    1.0000
%    23.3111   23.2004   30.2423    1.0000
% ...
%    69.7837   56.0656   59.2502    1.0000
%    70.9448   65.2384   98.7569   -1.0000
%    13.6795    1.2559   31.5993   -1.0000
%    89.3193   37.0548   62.3047   -1.0000

% %% [markdown]
% ## Plot the data

% %%
dataset.plot_3d()
